# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras import backend as K
print(K.backend())
# Download fashion dataset from Keras
fashion_mnist = tensorflow.keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = tensorflow.keras.datasets.fashion_mnist.load_data()

# Reshape and normalize the data
x_train = x_train.astype('float32').reshape(60000,28,28,1) / 255
x_test = x_test.astype('float32').reshape(10000,28,28,1) / 255


# Build a CNN model. You should see "INFO:plaidml:Opening device xxx" after you run this chunk
model = tensorflow.keras.Sequential()
model.add(tensorflow.keras.layers.Conv2D(filters=64, kernel_size=2, padding='same', activation='relu', input_shape=(28,28,1))) 
model.add(tensorflow.keras.layers.MaxPooling2D(pool_size=2))
model.add(tensorflow.keras.layers.Dropout(0.3))
model.add(tensorflow.keras.layers.Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(tensorflow.keras.layers.MaxPooling2D(pool_size=2))
model.add(tensorflow.keras.layers.Dropout(0.3))
model.add(tensorflow.keras.layers.Flatten())
model.add(tensorflow.keras.layers.Dense(256, activation='relu'))
model.add(tensorflow.keras.layers.Dropout(0.5))
model.add(tensorflow.keras.layers.Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss=tensorflow.keras.losses.sparse_categorical_crossentropy,
              metrics=['accuracy'])


# Fit the model on training set
model.fit(x_train, y_train,
          batch_size=64,
          epochs=10)

# Evaluate the model on test set
score = model.evaluate(x_test, y_test, verbose=0)
# Print test accuracy
print('\n', 'Test accuracy:', score[1])
# Out:
# tensorflow
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 87s 1ms/sample - loss: 0.5768 - accuracy: 0.7903
# Epoch 2/10
# 60000/60000 [==============================] - 101s 2ms/sample - loss: 0.4061 - accuracy: 0.8515
# Epoch 3/10
# 60000/60000 [==============================] - 103s 2ms/sample - loss: 0.3632 - accuracy: 0.8677
# Epoch 4/10
# 60000/60000 [==============================] - 102s 2ms/sample - loss: 0.3364 - accuracy: 0.8767
# Epoch 5/10
# 60000/60000 [==============================] - 110s 2ms/sample - loss: 0.3186 - accuracy: 0.8825
# Epoch 6/10
# 60000/60000 [==============================] - 89s 1ms/sample - loss: 0.2984 - accuracy: 0.8904
# Epoch 7/10
# 60000/60000 [==============================] - 103s 2ms/sample - loss: 0.2844 - accuracy: 0.8956
# Epoch 8/10
# 60000/60000 [==============================] - 120s 2ms/sample - loss: 0.2789 - accuracy: 0.8980
# Epoch 9/10
# ...

# %%
# !pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.1.0-cp37-cp37m-macosx_10_11_x86_64.whl (120.8 MB)
# Processing /Users/a955nd/Library/Caches/pip/wheels/7c/06/54/bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6/termcolor-1.1.0-cp37-none-any.whl
# ...
# Processing /Users/a955nd/Library/Caches/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd/gast-0.2.2-cp37-none-any.whl
# ...
#   Using cached tensorboard-2.1.1-py3-none-any.whl (3.8 MB)
# ...
#   Using cached grpcio-1.27.2-cp37-cp37m-macosx_10_9_x86_64.whl (2.5 MB)
# ...
# Processing /Users/a955nd/Library/Caches/pip/wheels/8e/28/49/fad4e7f0b9a1227708cbbee4487ac8558a7334849cb81c813d/absl_py-0.9.0-cp37-none-any.whl
# ...
#   Using cached opt_einsum-3.2.0-py3-none-any.whl (63 kB)
# ...
#   Using cached protobuf-3.11.3-cp37-cp37m-macosx_10_9_x86_64.whl (1.3 MB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# ...
#   Using cached tensorflow_estimator-2.1.0-py2.py3-none-any.whl (448 kB)
# ...
